# %%
# %%js
# class Poison {
#     constructor(name, toxicity, breed, sound, lifespan) {
#         this.name = name;
#         this.toxicity = toxicity;
#         this.breed = breed;
#         this.sound = sound;
#         this.lifespan = lifespan;
#     }
#
#     print() {
#         console.log(this.name, this.toxicity, this.breed, this.getSound(), this.lifespan);
#     }
#
#     getSound() {
#         return this.sound;
#         // Additional code to make sound goes here
#     }
# }
#
# class Bull extends Poison {
#     constructor(name, toxicity, breed, sound, lifespan) {
#         super(name, toxicity, breed, sound, lifespan);
#     }
#
#     // No need to override getSound if it behaves the same way
# }
#
# class Glass extends Poison {
#     constructor(name, toxicity, breed, sound, lifespan) {
#         super(name, toxicity, breed, sound, lifespan);
#     }
#
#     // No need to override getSound if it behaves the same way
# }
#
# class Greenings extends Poison {
#     constructor(name, toxicity, breed, sound, lifespan) {
#         super(name, toxicity, breed, sound, lifespan);
#     }
#
#     // No need to override getSound if it behaves the same way
# }
#
# var poisonName = "Jack";
# var poisonToxicity = "Poisonous";
# var poisonBreed = "Poison-Dart Frog";
# var poisonSound = "ribbit";
# var poisonLifespan = "15 years";
# var poison = new Poison(poisonName, poisonToxicity, poisonBreed, poisonSound, poisonLifespan);
#
# var bullName = "Michael";
# var bullToxicity = "Poisonous";
# var bullBreed = "Bull Frog";
# var bullSound = "ributt";
# var bullLifespan = "10 years"
# var bull = new Bull(bullName, bullToxicity, bullBreed, bullSound, bullLifespan);
#
# var glassName = "John";
# var glassToxicity = "Not Poisonous";
# var glassBreed = "Glass Frog";
# var glassSound = "bribit";
# var glassLifespan = "14 years";
# var glass = new Glass(glassName, glassToxicity, glassBreed, glassSound, glassLifespan);
#
# var greeningsName = "Green";
# var greeningsToxicity = "Poisonous";
# var greeningsBreed = "Greenings";
# var greeningsSound = "ribb";
# var greeningsLifespan = "16 years";
# var greenings = new Greenings(greeningsName, greeningsToxicity, greeningsBreed, greeningsSound, greeningsLifespan);
#
# var animals = [poison, bull, glass, greenings];
# for (var animal of animals) {
#     animal.print();
# }
